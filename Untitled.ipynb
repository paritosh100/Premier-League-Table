# %%
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

from plottable import ColumnDefinition , Table
from plottable.cmap import normed_cmap
from plottable.plots import image

# %%
df = pd.read_html("https://fbref.com/en/comps/9/2022-2023/2022-2023-Premier-League-Stats",attrs={"id":"results2022-202391_overall"})[0]

# %%
df.head()
# Out:
#    Rk            Squad  ...      Goalkeeper                                 Notes
# 0   1  Manchester City  ...         Ederson  → Champions League via league finish
# 1   2          Arsenal  ...  Aaron Ramsdale  → Champions League via league finish
# 2   3   Manchester Utd  ...    David de Gea  → Champions League via league finish
# 3   4    Newcastle Utd  ...       Nick Pope  → Champions League via league finish
# 4   5        Liverpool  ...         Alisson     → Europa League via league finish
#
# [5 rows x 19 columns]

# %%
df['Squad'].unique()
# Out:
# array(['Manchester City', 'Arsenal', 'Manchester Utd', 'Newcastle Utd',
#        'Liverpool', 'Brighton', 'Aston Villa', 'Tottenham', 'Brentford',
#        'Fulham', 'Crystal Palace', 'Chelsea', 'Wolves', 'West Ham',
#        'Bournemouth', "Nott'ham Forest", 'Everton', 'Leicester City',
#        'Leeds United', 'Southampton'], dtype=object)

# %%
df['badge'] = df['Squad'].apply(
    lambda x: f"D:/Python_practice/Premier league table/logos/{x.lower()}.png"
)

# %%
df['badge']
# Out:
# 0     D:/Python_practice/Premier league table/logos/...
# 1     D:/Python_practice/Premier league table/logos/...
# 2     D:/Python_practice/Premier league table/logos/...
# 3     D:/Python_practice/Premier league table/logos/...
# 4     D:/Python_practice/Premier league table/logos/...
# 5     D:/Python_practice/Premier league table/logos/...
# 6     D:/Python_practice/Premier league table/logos/...
# 7     D:/Python_practice/Premier league table/logos/...
# 8     D:/Python_practice/Premier league table/logos/...
# 9     D:/Python_practice/Premier league table/logos/...
# 10    D:/Python_practice/Premier league table/logos/...
# 11    D:/Python_practice/Premier league table/logos/...
# 12    D:/Python_practice/Premier league table/logos/...
# 13    D:/Python_practice/Premier league table/logos/...
# 14    D:/Python_practice/Premier league table/logos/...
# 15    D:/Python_practice/Premier league table/logos/...
# 16    D:/Python_practice/Premier league table/logos/...
# 17    D:/Python_practice/Premier league table/logos/...
# 18    D:/Python_practice/Premier league table/logos/...
# 19    D:/Python_practice/Premier league table/logos/...
# Name: badge, dtype: object

# %%
df.columns
# Out:
# Index(['Rk', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
#        'xG', 'xGA', 'xGD', 'xGD/90', 'Attendance', 'Top Team Scorer',
#        'Goalkeeper', 'Notes', 'badge'],
#       dtype='object')

# %%
df = df[[
        'Rk', 'badge', 'Squad', 'MP',
        'W', 'D', 'L', 'GF', 
        'GA', 'GD', 'Pts', 'Pts/MP',
        'xG', 'xGA', 'xGD', 'xGD/90'   
]]

# %%
df
# Out:
#     Rk                                              badge            Squad  MP   W  ...  Pts/MP    xG   xGA   xGD  xGD/90
# 0    1  D:/Python_practice/Premier league table/logos/...  Manchester City  38  28  ...    2.34  78.6  32.1  46.5    1.22
# 1    2  D:/Python_practice/Premier league table/logos/...          Arsenal  38  26  ...    2.21  71.9  42.0  29.9    0.79
# 2    3  D:/Python_practice/Premier league table/logos/...   Manchester Utd  38  23  ...    1.97  67.7  50.4  17.3    0.45
# 3    4  D:/Python_practice/Premier league table/logos/...    Newcastle Utd  38  19  ...    1.87  72.0  39.6  32.4    0.85
# 4    5  D:/Python_practice/Premier league table/logos/...        Liverpool  38  19  ...    1.76  72.6  50.9  21.7    0.57
# 5    6  D:/Python_practice/Premier league table/logos/...         Brighton  38  18  ...    1.63  73.3  50.2  23.1    0.61
# 6    7  D:/Python_practice/Premier league table/logos/...      Aston Villa  38  18  ...    1.61  50.2  52.5  -2.2   -0.06
# 7    8  D:/Python_practice/Premier league table/logos/...        Tottenham  38  18  ...    1.58  57.1  49.7   7.4    0.20
# 8    9  D:/Python_practice/Premier league table/logos/...        Brentford  38  15  ...    1.55  56.8  49.9   6.8    0.18
# 9   10  D:/Python_practice/Premier league table/logos/...           Fulham  38  15  ...    1.37  46.2  63.8 -17.6   -0.46
# 10  11  D:/Python_practice/Premier league table/logos/...   Crystal Palace  38  11  ...    1.18  39.3  48.1  -8.8   -0.23
# 11  12  D:/Python_practice/Premier league table/logos/...          Chelsea  38  11  ...    1.16  49.5  52.5  -3.0   -0.08
# 12  13  D:/Python_practice/Premier league table/logos/...           Wolves  38  11  ...    1.08  36.8  59.9 -23.1   -0.61
# 13  14  D:/Python_practice/Premier league table/logos/...         West Ham  38  11  ...    1.05  49.2  53.0  -3.9   -0.10
# 14  15  D:/Python_practice/Premier league table/logos/...      Bournemouth  38  11  ...    1.03  38.6  63.9 -25.3   -0.67
# 15  16  D:/Python_practice/Premier league table/logos/...  Nott'ham Forest  38   9  ...    1.00  39.3  64.2 -24.9   -0.66
# 16  17  D:/Python_practice/Premier league table/logos/...          Everton  38   8  ...    0.95  45.2  65.7 -20.5   -0.54
# 17  18  D:/Python_practice/Premier league table/logos/...   Leicester City  38   9  ...    0.89  50.6  63.4 -12.8   -0.34
# 18  19  D:/Python_practice/Premier league table/logos/...     Leeds United  38   7  ...    0.82  47.4  67.2 -19.8   -0.52
# 19  20  D:/Python_practice/Premier league table/logos/...      Southampton  38   6  ...    0.66  37.7  61.0 -23.3   -0.61
#
# [20 rows x 16 columns]

# %%
bg_color = "#FFFFFF"
text_color = "#000000"
row_color = {
    "top4": "#E1FABC",
    "top6": "#FFFC97",
    "relegation": "#E79A9A",
    "even": "#E2E2E1",
    "odd": "#B3B0B0",
}
plt.rcParams["text.color"] = text_color
plt.rcParams["font.family"] = "monospace"

# %%
df.columns
# Out:
# Index(['Rk', 'badge', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts',
#        'Pts/MP', 'xG', 'xGA', 'xGD', 'xGD/90'],
#       dtype='object')

# %%
col_defs = [
    ColumnDefinition(
        name = "Rk",
        textprops={"ha":"center"},
        width=0.5
    ),
    ColumnDefinition(
        name="badge",
        textprops={"ha":"center","va":"center","color":bg_color},
        width = 0.5,
        plot_fn=image
    ),
    ColumnDefinition(
        name = "Squad",
        textprops={"ha":"left","weight":"bold"},
        width=1.75
    ),
    ColumnDefinition(
        name = "MP",
        group="Matches Played",
        textprops={"ha":"center"},
        width=0.5
    ),
    ColumnDefinition(
        name = "W",
        group="Matches Played",
        textprops={"ha":"center"},
        width=0.5
    ),
    ColumnDefinition(
        name = "D",
        group="Matches Played",
        textprops={"ha":"center"},
        width=0.5
    ),
    ColumnDefinition(
        name = "L",
        group="Matches Played",
        textprops={"ha":"center"},
        width=0.5
    ),
    ColumnDefinition(
        name = "GF",
        group="Goals",
        textprops={"ha":"center"},
        width=0.5
    ),
    ColumnDefinition(
        name = "GA",
        group="Goals",
        textprops={"ha":"center"},
        width=0.5
    ),
    ColumnDefinition(
        name = "GD",
        group="Goals",
        textprops={"ha":"center"},
        width=0.5
    ),
    ColumnDefinition(
        name = "Pts",
        group="Points",
        textprops={"ha":"center"},
        width=0.5
    ),
    ColumnDefinition(
        name = "Pts/MP",
        group="Points",
        textprops={"ha":"center"},
        width=0.5
    ),
    ColumnDefinition(
        name="xG",
        group="Expected Goals",
        textprops={"ha":"center","color":text_color,"weight":"bold","bbox":{"boxstyle":"circle","pad":.35}},
        cmap=normed_cmap(df['xG'],cmap=matplotlib.cm.PiYG,num_stds=2)
 
    ),
    ColumnDefinition(
        name="xGA",
        group="Expected Goals",
        textprops={"ha":"center","color":text_color,"weight":"bold","bbox":{"boxstyle":"circle","pad":.35}},
        cmap=normed_cmap(df['xG'],cmap=matplotlib.cm.PiYG_r,num_stds=2)
 
    ),
    ColumnDefinition(
        name="xGD",
        group="Expected Goals",
        textprops={"ha":"center","color":text_color,"weight":"bold","bbox":{"boxstyle":"circle","pad":.35}},
        cmap=normed_cmap(df['xG'],cmap=matplotlib.cm.PiYG,num_stds=2)
 
    )
]

# %%
fig,ax = plt.subplots(figsize=(20,22))
fig.set_facecolor(bg_color)
ax.set_facecolor(bg_color)

table = Table(
    df,
    column_definitions=col_defs,
    index_col="Rk",
    row_dividers=True,
    row_divider_kw={"linewidth":1,"linestyle":(0,(1,5))},
    footer_divider=True,
    textprops={"fontsize":14},
    ax = ax
).autoset_fontcolors(colnames=['xG',"xGA","xGD"])

# %%
fig.savefig(
    "D:/Python_practice/Premier league table/PremierLeague_table.png",
    facecolor=ax.get_facecolor(),
    dpi=200,
    bbox_inches="tight",
)

# %%
table.cells[10, 3]
# Out:
# TextCell(xy=(2.75, 10), content=38, row_idx=10, col_idx=3)
